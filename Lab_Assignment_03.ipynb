# %% [markdown]
# 1.   Be careful in which question you are required to change the given Linked list and where you are required to create a new one
# 2.   Be careful of the first node and the last node [aka corner cases]
# 3.   Do not use any other data structure other than Linked List

# %% [markdown]
# ***You must run this cell to install dependency***

# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# Requirement already satisfied: fhm-unittest in c:\users\sujit kumar\appdata\local\programs\python\python310\lib\site-packages (1.0.1)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: fuzzywuzzy in c:\users\sujit kumar\appdata\local\programs\python\python310\lib\site-packages (0.18.0)
# WARNING: There was an error checking the latest version of pip.
# c:\Users\SUJIT KUMAR\AppData\Local\Programs\Python\Python310\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
#  ***You must Run this cell for your driver code to execute successfully***

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None):
    self.elem,self.next = elem,next

def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head

def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %%
# User defined helping function to solve this assignments problems

def lastNode(head):
  temp = head
  while (temp.next != None):
    temp = temp.next
  return temp

def left(head):
    temp = head
    head = head.next
    last = lastNode(head)
    last.next = temp
    temp.next = None
    return head

def nodeAt(head, idx):

  temp = head
  count = 0
  while temp.next != None:

    if count == idx : 
      return temp
    else: 
      count +=1
      
    temp = temp.next
  return temp

def insertion(head, elem, idx):

    if idx == 0:
        # temp = head
        new = Node(elem, head)
        head = new
    else:
        prev = nodeAt(head, idx-1)
        current = prev.next
        new = Node(elem, current)
        prev.next = new

    return head

def deletion(head, idx):

  if idx != 0:
    prev = nodeAt(head, idx-1)
    current = prev.next
    prev.next = prev.next.next
    current = None
  else:
    head = head.next

    return head

# %%
## ................Rough cell........
def insertion(head):
    if head is None: return True

def maxValue(head):

    max = head
    temp = head
    while (temp != None):
        if (max.elem < temp.elem):
            max = temp
        temp = temp.next
    newHead = max
    newTemp = newHead
    # while temp != None:
    #     while newTemp != None:
    return max

def insertion(head, elem, idx):
    if idx == 0:
        temp = head
        head = head.next
        temp = None
    else:
        prev = nodeAt(head, idx-1)
        current = prev.next
        new = Node(elem, current)
        prev.next = new
        # current.next = None
    return head

head = createList(np.array([13,10,6,20,17]))
m = maxValue(head)
print(printLinkedList(insertion(head, 19, 2)))
print(m.elem)
# Out:
# 13-->10-->19-->6-->20-->17
#
# None
# 20

# %% [markdown]
# Number Beads

# %%
# ...........Complete........



def maxValue(head):

    max = head
    temp = head
    while (temp != None):
        if (max.elem < temp.elem):
            max = temp
        temp = temp.next
    return max

def rotation_times(head):
  #To DO
  original = maxValue(head)
  count = 0
  while True:
      
      if head.elem == original.elem:
          break
      temp = head
      last = lastNode(head)
      last.next = head
      head = head.next
      temp.next = None
      count += 1

  return count


print('==============Test Case 1=============')
head = createList(np.array([13,10,6,20,17]))
print('Rearranged Necklace: ', end = ' ')
printLinkedList(head)
returned_value = rotation_times(head)
print(f'Rotated: {returned_value} times') #This should print 3
unittest.output_test(returned_value, 3)
print()

print('==============Test Case 2=============')
head = createList(np.array([6,20,17,13,10]))
print('Rearranged Necklace: ', end = ' ')
printLinkedList(head)
returned_value = rotation_times(head)
print(f'Rotated: {returned_value} times') #This should print 1
unittest.output_test(returned_value, 1)
print()

print('==============Test Case 3=============')
head = createList(np.array([20,17,13,10,6]))
print('Rearranged Necklace: ', end = ' ')
printLinkedList(head)
returned_value = rotation_times(head)
print(f'Rotated: {returned_value} times') #This should print 0
unittest.output_test(returned_value, 0)
print()
# Out:
# ==============Test Case 1=============
# Rearranged Necklace:  13-->10-->6-->20-->17
#
# Rotated: 3 times
# Accepted
#
# ==============Test Case 2=============
# Rearranged Necklace:  6-->20-->17-->13-->10
#
# Rotated: 1 times
# Accepted
#
# ==============Test Case 3=============
# Rearranged Necklace:  20-->17-->13-->10-->6
#
# Rotated: 0 times
# Accepted

# %% [markdown]
# Building Blocks

# %%
#............Complete........
# Can we use try except to solve this problem.?

def check_similar(building_1, building_2):
  #TO DO
  temp1 = building_1
  temp2 = building_2
  try:
    while temp1.next != None or temp2.next != None:
      if temp1.elem != temp2.elem:
        return "Not Similar"
      temp1 = temp1.next
      temp2 = temp2.next
  except:
    return "Not Similar"
  return "Similar"


print('==============Test Case 1=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Similar'
unittest.output_test(returned_value, 'Similar')
print()

print('==============Test Case 2=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Yellow', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()

print('==============Test Case 3=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green', 'Blue']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()

print('==============Test Case 4=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green', 'Blue']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()
# Out:
# ==============Test Case 1=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Similar
# Accepted
#
# ==============Test Case 2=============
# Building 1:  Red-->Green-->Yellow-->Red-->Yellow-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Not Similar
# Accepted
#
# ==============Test Case 3=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green-->Blue
#
# Not Similar
# Accepted
#
# ==============Test Case 4=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green-->Blue
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Not Similar
# Accepted

# %% [markdown]
# Remove Compartment

# %%
# ..........Complete..........



def remove_compartment(head,n):
  
  temp = head
  occur = 0
  while temp != None:
    if temp.elem == n:
      occur +=1
    temp = temp.next
  
  if occur == 0:
    return head
  
  elif head.elem == n:
    newHead = deletion(head, 0)
    return newHead
  
  else:

    flag = head.next
    count = 0
    idx = 0
    while flag != None:
      idx += 1

      if flag.elem == n:
        count += 1

      if count == occur:
        prev = nodeAt(head, idx-1)
        # current = prev.next
        prev.next = prev.next.next
        # current = None
        flag = None
        break

      flag = flag.next

  return head



print('==============Test Case 1=============')
head = createList(np.array([14,10,15,10,41,10,72]))
number = 10
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 14-->10-->15-->10-->41-->72
print()

print('==============Test Case 2=============')
head = createList(np.array([10,15,33,41,14,72]))
number = 10
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 15-->33-->41-->14-->72
print()

print('==============Test Case 3=============')
head = createList(np.array([10,15,33,41,14,72]))
number = 56
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 10-->15-->33-->41-->14-->72
print()
# Out:
# ==============Test Case 1=============
# Original Compartment Sequence:  14-->10-->15-->10-->41-->10-->72
#
# Changed Compartment Sequence:  14-->10-->15-->10-->41-->72
#
#
# ==============Test Case 2=============
# Original Compartment Sequence:  10-->15-->33-->41-->14-->72
#
# Changed Compartment Sequence:  15-->33-->41-->14-->72
#
#
# ==============Test Case 3=============
# Original Compartment Sequence:  10-->15-->33-->41-->14-->72
#
# Changed Compartment Sequence:  10-->15-->33-->41-->14-->72

# %% [markdown]
# Capture the Flag

# %%
def capture_the_flag(head):
  #To Do
  newIdx = 0
  newHead = head
  newTemp = newHead
  idx = 1
  temp = head
  while temp != None:
    if (temp.elem %idx) != 0:
      return "Linkwise"
    if newIdx == 0:
      newHead = Node(temp.elem//idx,None)
      newTemp = newHead
      newIdx += 1
    else:
      newTemp.next = Node(temp.elem//idx,None)
      newTemp = newTemp.next
    temp = temp.next
    idx += 1
  return newHead

print('==============Test Case 1=============')
head = createList(np.array([11,8,21,20,5,42]))
print('Original Sequence: ', end = ' ')
printLinkedList(head)
new_head = capture_the_flag(head)
print('The flag is: ', end= ' ')
if type(new_head) == str:
  print(new_head)
else:
  printLinkedList(new_head) #This should print 11→4→7→5→1→7
print()

print('==============Test Case 2=============')
head = createList(np.array([11,8,28,20,5,42]))
print('Original Sequence: ', end = ' ')
printLinkedList(head)
new_head = capture_the_flag(head)
print('The flag is: ', end= ' ')
if type(new_head) == str:
  print(new_head) #This should print Linkwise
else:
  printLinkedList(new_head)
print()
# Out:
# ==============Test Case 1=============
# Original Sequence:  11-->8-->21-->20-->5-->42
#
# The flag is:  11-->4-->7-->5-->1-->7
#
#
# ==============Test Case 2=============
# Original Sequence:  11-->8-->28-->20-->5-->42
#
# The flag is:  Linkwise

# %% [markdown]
# Shuffle on song

# %%
def shuffle_on_song(head):
  #To DO
  oddHead = None
  oddCount = 0
  oddTemp = head
  evenHead = head
  evenTemp = head
  evenCount = 0
  temp = head
  store = None
  while temp != None:
    if (ord(temp.elem) % 2 !=0 ):
      if oddCount ==0:
        oddHead = temp
        oddTemp = temp
        oddCount += 1
      else:
        oddTemp.next = temp
        oddTemp = temp
    else:
      if evenCount ==0:
        evenHead = temp
        evenTemp = temp
        evenCount += 1
      else:
        evenTemp.next = temp
        evenTemp = temp
    store = temp
    temp = temp.next
    store.next = None
  last = lastNode(evenHead)
  last.next = oddHead

  return evenHead

print('==============Test Case 1=============')
head = createList(np.array(['S','E','N','P','A','I']))
print('Original Play List: ', end = ' ')
printLinkedList(head)
newhead =  shuffle_on_song(head)
print('New Play List: ', end = ' ')
printLinkedList(newhead) #This should print N-->P-->S-->E-->A-->I
print()

print('==============Test Case 2=============')
head = createList(np.array(['N','I','S','H','I','N','O','Y','A']))
print('Original Play List: ', end = ' ')
printLinkedList(head)
newhead =  shuffle_on_song(head)
print('New Play List: ', end = ' ')
printLinkedList(newhead) #This should print N-->H-->N-->I-->S-->I-->O-->Y-->A
print()
# Out:
# ==============Test Case 1=============
# Original Play List:  S-->E-->N-->P-->A-->I
#
# New Play List:  N-->P-->S-->E-->A-->I
#
#
# ==============Test Case 2=============
# Original Play List:  N-->I-->S-->H-->I-->N-->O-->Y-->A
#
# New Play List:  N-->H-->N-->I-->S-->I-->O-->Y-->A

# %% [markdown]
# BONUS

# %% [markdown]
# Assemble Conga Line

# %%
def assemble_conga_line(conga_line, candidate_line, idx):
  #To Do

  temp = conga_line
  position = 0
  while temp != None:
    if idx == 0:
      minValue = candidate_line.elem
      minNode = candidate_line
      candiTemp = candidate_line
      # chk1 = temp.elem - candiTemp.elem
      while candiTemp != None:
        if candiTemp.elem <= temp.elem:
          chk2 =  temp.elem - candiTemp.elem
          if  chk2 >0 and minValue > chk2 :
            minValue = chk2
            minNode = candiTemp
          # elif chk1 > 0 and chk2 >0 and chk2 > chk1:
          #   minValue = chk1
          #   minNode = candiTemp
        candiTemp = candiTemp.next
      back = insertion(conga_line, minNode.elem, idx)
      return back

    elif position == idx:
      minValue = None
      minNode = None
      prev = nodeAt(conga_line, idx-1)
      candiTemp = candidate_line
      while candiTemp != None:
        if prev.elem <= candiTemp.elem <= temp.elem:
          chk1 = candiTemp.elem - prev.elem
          chk2 =  temp.elem - candiTemp.elem
          if chk1 > 0 and chk2 >0 and chk1 > chk2 :
            minValue = chk2
            minNode = candiTemp
          elif chk1 > 0 and chk2 >0 and chk2 > chk1:
            minValue = chk1
            minNode = candiTemp
        candiTemp = candiTemp.next
      if minNode != None:
        back = insertion(conga_line, minNode.elem, idx)
        return conga_line
    position += 1
    temp = temp.next
  return conga_line


print('==============Test Case 1=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([16,2,36,52,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 3
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 10-->15-->34-->40-->41-->56-->72
printLinkedList(returned_value)

print('==============Test Case 2=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([6,16,8,36,7,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 0
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 8-->10-->15-->34-->41-->56-->72
printLinkedList(returned_value)

print('==============Test Case 3=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([6,12,8,36,7,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 2
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 10-->15-->34-->41-->56-->72
printLinkedList(returned_value)
# Out:
# ==============Test Case 1=============
# Original Conga Line:  10-->15-->34-->41-->56-->72
#
# Original candidate Line:  16-->2-->36-->52-->40-->77
#
# Changed Conga Line:  10-->15-->34-->40-->41-->56-->72
#
# ==============Test Case 2=============
# Original Conga Line:  10-->15-->34-->41-->56-->72
#
# Original candidate Line:  6-->16-->8-->36-->7-->40-->77
#
# Changed Conga Line:  8-->10-->15-->34-->41-->56-->72
#
# ==============Test Case 3=============
# Original Conga Line:  10-->15-->34-->41-->56-->72
#
# Original candidate Line:  6-->12-->8-->36-->7-->40-->77
#
# Changed Conga Line:  10-->15-->34-->41-->56-->72
